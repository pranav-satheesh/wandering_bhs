# %% [markdown]
# ### Setting up the environment
#
# First thing to do is creating a fresh conda environment so the package and its dependencies stay isolated from your other projects.
#
# I like to keep all of my helper codes and functions here in https://github.com/pranav-satheesh/cosmo_sim_tools. Clone this directory to your home and follow the instructions in the readme to install the package in to your conda environment.

# %% [markdown]
# ```bash
# git clone https://github.com/pranav-satheesh/cosmo_sim_tools.git
# cd cosmo_sim_tools
#
# # create the environment from the provided file (installs deps + the package itself)
# conda env create -f environment.yml
# conda activate cosmo_sim_tools
#
# # register this environment so it shows up as a Jupyter kernel
# python -m ipykernel install --user --name cosmo_sim_tools
# ```

# %% [markdown]
# Now restart Jupyter and, using the **kernel selector at the top-right of the
# notebook**, choose the `cosmo_sim_tools` kernel. Everything below runs in that kernel.

# %%
import numpy as np
import matplotlib.pyplot as plt

# The editable install means we can import this anywhere, no sys.path hacks needed.
import cosmo_sim_tools as cosmosim

# NOTE: importing the top-level package does NOT pull in the subpackages,
# so we import the helpers explicitly:
from cosmo_sim_tools.arepo_tools import arepo_package
from cosmo_sim_tools import illustris as il
from cosmo_sim_tools import brahma

# %% [markdown]
# ## Loading up the Simulation files

# %% [markdown]
# ### 2. Reading simulation files with `arepo_package`
#
# `output_path` is the directory holding the AREPO outputs for one run — the folder
# that contains the `groups_XXX/` (group catalogs) and `snapdir_XXX/` (snapshots)
# subfolders. On HiPerGator our runs live under `/orange/lblecha/...`, e.g.:

# %%
#The simulation outputs are stored in orange. Let's take a look at one of the BRAHMA simulation data

Brahma_sim_path = '/orange/lblecha/aklantbhowmick/GAS_BASED_SEED_MODEL_UNIFORM_RUNS/L12p5n512/AREPO/'
#I encourage you to cd in to this directory in your terminal and see all the different runs within this directory. 
#Each run has a different seed for the initial conditions, and the seed is encoded in the name of the run. 
#For example, the run 'L12p5n512' stands for a volume of 12.5h^-1 Mpc^3 box with 512^3 particle resolution
#All of these are some variations of the simulation with the same box size and particle resolution.
#Let us check one of this
Brahma_sim_name = 'SM5_DFD_3_TNG/'
#Don't worry about the nomenclature for now.
Brahma_sim_file = Brahma_sim_path+Brahma_sim_name

# %%
# Which snapshots exist, and what redshift does each correspond to?
snapshots, redshifts = arepo_package.get_snapshot_redshift_correspondence(Brahma_sim_file)
for snap, z in zip(snapshots, redshifts):
    print(f"snapshot {snap:>3d}  ->  z = {z:.3f}")
# Out:
# snapshot   0  ->  z = 25.048
# snapshot   1  ->  z = 23.961
# snapshot   2  ->  z = 23.032
# snapshot   3  ->  z = 22.029
# snapshot   4  ->  z = 20.963
# snapshot   5  ->  z = 20.046
# snapshot   6  ->  z = 18.978
# snapshot   7  ->  z = 17.963
# snapshot   8  ->  z = 17.000
# snapshot   9  ->  z = 16.005
# snapshot  10  ->  z = 14.989
# snapshot  11  ->  z = 14.034
# snapshot  12  ->  z = 13.003
# snapshot  13  ->  z = 11.980
# snapshot  14  ->  z = 10.976
# snapshot  15  ->  z = 9.997
# snapshot  16  ->  z = 9.002
# snapshot  17  ->  z = 8.012
# snapshot  18  ->  z = 7.005
# snapshot  19  ->  z = 6.011
# snapshot  20  ->  z = 4.996
# snapshot  21  ->  z = 4.008
# snapshot  22  ->  z = 3.008
# snapshot  23  ->  z = 2.002
# snapshot  24  ->  z = 1.496
# snapshot  25  ->  z = 0.997
# snapshot  26  ->  z = 0.700
# snapshot  27  ->  z = 0.503
# snapshot  28  ->  z = 0.400
# snapshot  29  ->  z = 0.298
# snapshot  30  ->  z = 0.197
# snapshot  31  ->  z = 0.099
# ...

# %%
# grab a valid snapshot number
snap = snapshots[0]

# read everything straight from the BRAHMA group-catalog header
header  = brahma.groupcat.loadHeader(Brahma_sim_file, snap)
om0     = header['Omega0']
oml     = header['OmegaLambda']
h       = header['HubbleParam']
boxsize = header['BoxSize']

print(f"Omega_m={om0}, Omega_L={oml}, h={h}, boxsize={boxsize}")
# Out:
# Omega_m=0.3089, Omega_L=0.6911, h=0.6771, boxsize=12500.0

# %% [markdown]
# There are three functions in arepo_package used to load the data from brahma sims. **Each returns a tuple `(data, output_redshift)`**,
# where `output_redshift` is the actual redshift of the snapshot it read (the closest one
# to what you asked for):
#
# | Function | Reads | Example fields |
# |---|---|---|
# | `get_group_property`    | FoF halos (groups)   | `Group_M_Crit200`, `GroupPos`, `GroupFirstSub` |
# | `get_subhalo_property`  | SUBFIND subhalos     | `SubhaloMassType`, `SubhaloPos`, `SubhaloVel` |
# | `get_particle_property` | raw particles        | `Coordinates`, `Masses`, `BH_Mass` |
#
# For particles you also pass a **particle type** `p_type`:
#
# `0` = gas  ·  `1` = dark matter  ·  `4` = stars  ·  `5` = black holes.
#
# Read more about what these quanitites mean in IllustrisTNG documentation

# %%
desired_redshift = 5.0
#Let us check the group catalog (halos), subhalo catalog (Subhalos, galaxies) and the particles in this redshift.

# --- Group (halo) catalog ---
halo_masses, z = arepo_package.get_group_property(Brahma_sim_file, "GroupMass", desired_redshift)
print(f"number of FoF groups or halos: {len(halo_masses)}, at z ={z:.3f}")

# --- Subhalo catalog ---
subhalo_masstype, z = arepo_package.get_subhalo_property(Brahma_sim_file, "SubhaloMassType", desired_redshift)

#TO-DO: Check the shape of subhalo_masstype. What do you see? What does it stand for? 
#Check the TNG documentation for help:  https://www.tng-project.org/data/docs/specifications/#sec2a
print(subhalo_masstype.shape)
#The shape is (112107, 6). From the website: "Total mass of all member particle/cells which are bound to this Subhalo, separated by type. 
# Particle/cells bound to subhaloes of this Subhalo are NOT accounted for. 
# Note: Wind phase cells are counted as gas (type 0) for SubhaloMassType"
# This is an array covering 112,107 subhalos from the snapshot, and giving the total mass of each of the six particle types.

# --- Particles (note the p_type argument) ---
gas_coords, z = arepo_package.get_particle_property(Brahma_sim_file, "Coordinates", 0, desired_redshift)  # gas
print(f"Shape of gas_coords result: {gas_coords.shape}")
bh_mass,    z = arepo_package.get_particle_property(Brahma_sim_file, "BH_Mass",     5, desired_redshift)  # black holes
print(f"number of black holes : {len(bh_mass)}, at z ={z:.3f}")
# Out:
# number of FoF groups or halos: 119441, at z =4.996
# (112107, 6)
# Desired redshift:  5.0
# Output redshift:  4.995933468164624
# Output snapshot:  20
# Shape of gas_coords result: (131992706, 3)
# Desired redshift:  5.0
# Output redshift:  4.995933468164624
# Output snapshot:  20
# number of black holes : 20156, at z =4.996

# %%
z

# %%
# Let us plot the Halo mass function: distribution of FoF halo masses (units: 1e10 Msun/h)
# Note: FoF = Friends of Friends. Particles are friends within a certain distance, and form networks. I assume one network is one halo.
hmf = halo_masses * 1e10/h
plt.hist(np.log10(hmf[hmf > 0]), bins=10,histtype='step')
plt.xlabel(r"$\log_{10}(M_{\rm halo}\ [M_\odot])$")
plt.ylabel("number of halos")
plt.yscale('log',base=10)
plt.title(f"z = {z:2.3f}")
plt.show()

# %%
snap = 2  # the specific snapshot you want to inspect

# per-type particle counts for every subhalo in this snapshot  ->  shape [N_subhalos, 6]
subhalo_lentype = brahma.groupcat.loadSubhalos(Brahma_sim_file, snap, fields="SubhaloLenType")

subhalo_index = 0                        # pick one subhalo
n_bh = subhalo_lentype[subhalo_index][5]  # particle type 5 = black holes

print(f"snapshot {snap}: subhalo {subhalo_index} has {n_bh} black hole(s) ")

# %%
snap = 20  # the specific snapshot you want to inspect

# per-type particle counts for every subhalo in this snapshot  ->  shape [N_subhalos, 6]
subhalo_lentype = brahma.groupcat.loadSubhalos(Brahma_sim_file, snap, fields="SubhaloLenType")

subhalo_index = 0                        # pick one subhalo
n_bh = subhalo_lentype[subhalo_index][5]  # particle type 5 = black holes

print(f"snapshot {snap}: subhalo {subhalo_index} has {n_bh} black hole(s) ")

# %% [markdown]
# Woah! That is a huge jump in the number of BHs in these two subhalos. What redshifts are we looking at ?

# %%
#check the redshifts for the above two snapshots.
#From the above table, snapshot 0 is at a redshift of z=25.048 and snapshot 20 is at z=4.996, the same one we graphed.

#play around with BHs in other subhalos and snapshots

# %%
n_bh_arr = np.empty(33)
for i in range(33):
    n_bh_arr[i] = brahma.groupcat.loadSubhalos(Brahma_sim_file, i, fields="SubhaloLenType")[0][5]

print(f"Subhalo 0 started with {n_bh_arr[0]} at snapshot 0 and had {n_bh_arr[20]} at 20")

# %%
plt.plot(np.arange(0,33), n_bh_arr)
plt.xlabel("Snapshot")
plt.ylabel("Number of Black Holes in Subhalo 0")
plt.show()

# %% [markdown]
# ### Number of BHs versus Subhalo Masses

# %% [markdown]
# Now, you are set to probe this question. Do larger subhalos produce more number of wandering BHs? How does this vary with redshifts?
#
# #TO-DO:
# Pick a redshift and get all the subhalo masses and their respective number of BHs in them. Make a plot of the number of BHs versus the subhalo masses. Change the axes to log-scale if required. Now, try a different redshift, does the interpretation change at different redshifts?

# %%
# Starting with redshift ~ 5 (snapshot 20)
n_bh_arr_snap20 = subhalo_lentype[:, 5]
subhalo_mass_snap20 = brahma.groupcat.loadSubhalos(Brahma_sim_file, 20, fields="SubhaloMass")
# subhalomass field is measured in 10^10 solar mass / h. idk what h means.
# mass in Msol = 10^10 * given mass. log(mass in Msol) = log(10^10) + log(given mass) = 10 + log(given mass)

# %%
plt.scatter(np.log10(subhalo_mass_snap20)+10, np.log(n_bh_arr_snap20))
plt.xlabel(r"$\log_{10}(M_{\rm halo} [M_{\odot}])$")
plt.ylabel(r"$\log_{10}(N_{\rm BH})$")
plt.title("Snapshot 20")

# %%
# Compared to redshift ~ 0.2 (snapshot 30)
n_bh_arr_snap30 = brahma.groupcat.loadSubhalos(Brahma_sim_file, 30, fields="SubhaloLenType")[:, 5]
subhalo_mass_snap30 = brahma.groupcat.loadSubhalos(Brahma_sim_file, 30, fields="SubhaloMass")

# %%
plt.scatter(np.log10(subhalo_mass_snap30)+10, np.log(n_bh_arr_snap30))
plt.xlabel(r"$\log_{10}(M_{\rm halo} [M_{\odot}])$")
plt.ylabel(r"$\log_{10}(N_{\rm BH})$")
plt.title("Snapshot 30")

# %%
for i in [3, 4, 5, 6]:
    plt.scatter(np.log10(brahma.groupcat.loadSubhalos(Brahma_sim_file, 5*i, fields="SubhaloMass"))+10, np.log(brahma.groupcat.loadSubhalos(Brahma_sim_file, 5*i, fields="SubhaloLenType")[:, 5]), s=5, label=str(5*i))
plt.xlabel(r"$\log_{10}(M_{\rm halo} [M_{\odot}])$")
plt.ylabel(r"$\log_{10}(N_{\rm BH})$")
plt.legend()
plt.title("#BH to Halo Mass by snapshot (in fives)")

# %%
# It appears that over time, the plot shifts up and to the right: low-mass halos have less black holes, and high mass halos have more.

# %% [markdown]
# ## Number of Black Holes vs Stellar Mass

# %%
def filter_arrays(snapshot, num_bins):
    stellar_mass = brahma.groupcat.loadSubhalos(Brahma_sim_file, snapshot, fields="SubhaloMassType")[:,4]
    nonzero_indices = np.where(stellar_mass>1e-4)
    stellar_mass_log = np.log10(stellar_mass[nonzero_indices])+10
    nbh_nonzero_log = np.log10((brahma.groupcat.loadSubhalos(Brahma_sim_file, snapshot, fields="SubhaloLenType")[:, 5])[nonzero_indices])
    bins = np.linspace(stellar_mass_log.min(), stellar_mass_log.max(), num_bins+1)
    return bins, stellar_mass_log, nbh_nonzero_log

# %%
def med_nbh_vs_stellar_at_snap(snapshot, num_bins):
    bins, stellar_mass_log, nbh_nonzero_log = filter_arrays(snapshot, num_bins)
    medians = np.empty(num_bins)
    fifths = np.empty(num_bins)
    ninety_fifths = np.empty(num_bins)
    for i in range(num_bins):
        binset = nbh_nonzero_log[np.where(np.logical_and(bins[i]<stellar_mass_log, stellar_mass_log<bins[i+1]))]
        if binset.size == 0: 
            medians[i] = 0
            fifths[i] = 0
            ninety_fifths[i] = 0
        else:
            medians[i] = np.median(binset)
            fifths[i] = np.percentile(binset, 5)
            ninety_fifths[i] = np.percentile(binset, 95)
    return bins, medians, fifths, ninety_fifths

# %%
def mean_nbh_vs_stellar_at_snap(snapshot, num_bins):
    bins, stellar_mass_log, nbh_nonzero_log = filter_arrays(snapshot, num_bins)
    means = np.empty(num_bins)
    stdevs = np.empty(num_bins) #change to percentiles
    for i in range(num_bins):
        binset = nbh_nonzero_log[np.where(np.logical_and(bins[i]<stellar_mass_log, stellar_mass_log<bins[i+1]))]
        if binset.size == 0: 
            means[i] = 0
            stdevs[i] = 0
        else:
            means[i] = np.mean(binset)
            stdevs[i] = np.std(binset)
    return bins, means, stdevs

# %%
snap32bins, snap32meds, snap32fp, snap32nfp = med_nbh_vs_stellar_at_snap(32, 30)
plt.stairs(snap32meds, snap32bins)
# Out:
# /tmp/ipykernel_1709954/4070447982.py:5: RuntimeWarning: divide by zero encountered in log10
#   nbh_nonzero_log = np.log10((brahma.groupcat.loadSubhalos(Brahma_sim_file, snapshot, fields="SubhaloLenType")[:, 5])[nonzero_indices])

# %%
snap32bins, snap32means, snap32stds = mean_nbh_vs_stellar_at_snap(32, 30)
plt.stairs(snap32means, snap32bins)
# Out:
# /tmp/ipykernel_1709954/4070447982.py:5: RuntimeWarning: divide by zero encountered in log10
#   nbh_nonzero_log = np.log10((brahma.groupcat.loadSubhalos(Brahma_sim_file, snapshot, fields="SubhaloLenType")[:, 5])[nonzero_indices])

# %%
snap_choices = [32, 20, 15, 10] # z = 0, 5, 10, 15. Tried s=5 and 0, snap=20 and 25, but there were no halos in the range
for s in snap_choices: 
    snapchoicebins, snapchoicemeds, snapchoicefifths, snapchoiceninetyfifths = med_nbh_vs_stellar_at_snap(s, 15)
    plt.stairs(snapchoicemeds, snapchoicebins)
    plt.fill_between(snapchoicebins[:-1], snapchoicefifths, snapchoiceninetyfifths, step="post", alpha=0.5)
# Out:
# /tmp/ipykernel_1709954/4070447982.py:5: RuntimeWarning: divide by zero encountered in log10
#   nbh_nonzero_log = np.log10((brahma.groupcat.loadSubhalos(Brahma_sim_file, snapshot, fields="SubhaloLenType")[:, 5])[nonzero_indices])

# %%
snap_choices = [32, 20, 15, 10] # z = 0, 5, 10, 15
for s in snap_choices: 
    snapchoicebins, snapchoicemeans, snapchoicestds = mean_nbh_vs_stellar_at_snap(s, 25)
    plt.stairs(snapchoicemeans, snapchoicebins)
    plt.fill_between(snapchoicebins[:-1], snapchoicemeans-snapchoicestds, snapchoicemeans+snapchoicestds, step="post", alpha=0.5)
# Out:
# /tmp/ipykernel_1709954/4070447982.py:5: RuntimeWarning: divide by zero encountered in log10
#   nbh_nonzero_log = np.log10((brahma.groupcat.loadSubhalos(Brahma_sim_file, snapshot, fields="SubhaloLenType")[:, 5])[nonzero_indices])

# %%
snap_choices = np.arange(9, 32, 2)
for s in snap_choices: 
    snapchoicebins, snapchoicemeds, snapchoicefifths, snapchoiceninetyfifths = med_nbh_vs_stellar_at_snap(s, 25)
    plt.stairs(snapchoicemeds, snapchoicebins)
    plt.fill_between(snapchoicebins[:-1], snapchoicefifths, snapchoiceninetyfifths, step="post", alpha=0.5)
# Out:
# /tmp/ipykernel_1709954/4070447982.py:5: RuntimeWarning: divide by zero encountered in log10
#   nbh_nonzero_log = np.log10((brahma.groupcat.loadSubhalos(Brahma_sim_file, snapshot, fields="SubhaloLenType")[:, 5])[nonzero_indices])

# %%
snap_choices = np.arange(9, 32, 2) #note: doesn't run below snap 9
for s in snap_choices: 
    snapchoicebins, snapchoicemeans, snapchoicestds = mean_nbh_vs_stellar_at_snap(s, 25)
    plt.stairs(snapchoicemeans, snapchoicebins)
    plt.fill_between(snapchoicebins[:-1], snapchoicemeans-snapchoicestds, snapchoicemeans+snapchoicestds, step="post", alpha=0.5)
# Out:
# /tmp/ipykernel_1709954/4070447982.py:5: RuntimeWarning: divide by zero encountered in log10
#   nbh_nonzero_log = np.log10((brahma.groupcat.loadSubhalos(Brahma_sim_file, snapshot, fields="SubhaloLenType")[:, 5])[nonzero_indices])

# %%
# These all seem linear on the log-log, just with different intercepts and starting points. 
# The slope seems around 0.5 (roughly) which implies a square root relation (n_bh=a*sqrt(m_stell))

# %%
#notes: change to line

# %%
edges = np.array([5, 10, 20, 50, 55])
mids = (edges[:-1]+edges[1:])/2

# %%
mids
# Out:
# array([ 7.5, 15. , 35. , 52.5])
